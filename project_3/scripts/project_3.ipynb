# %%
# packages for data processing
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import pyplot as plt

# packages for linear model
import statsmodels
import statsmodels.formula.api as smf
import statsmodels.api as sm

# %%
# convert date into datetime type
def parse_date(string):
    month, day, year = string.split('/')
    return datetime(int(year), int(month), int(day))

# extract number of days from datetime
def stay(time):
    return time.days

def remove_HUD(string):
    return string[:-6]

# %%
# read and select data with parameters of interest
client_background = ["Client ID", "Client Age at Entry", "Client Gender", "Client Primary Race", "Client Ethnicity", "Client Veteran Status"]
duration_interest = ['Client ID', 'Entry Date', 'Exit Date']
client = pd.read_csv("https://raw.githubusercontent.com/datasci611/bios611-projects-fall-2019-Jianqiao-Wang/master/project_3/data/CLIENT_191102.tsv", sep="\t")[client_background]
duration = pd.read_csv("https://raw.githubusercontent.com/datasci611/bios611-projects-fall-2019-Jianqiao-Wang/master/project_3/data/ENTRY_EXIT_191102.tsv", sep="\t")[duration_interest]

# %%
# join two datasets by client ID
data = pd.concat([duration, client], axis=1, join="inner")

# replace cells with NAN
data.replace('Data not collected (HUD)', np.nan, inplace=True)
data.replace("Client doesn't know (HUD)", np.nan, inplace=True)
data.replace('Client refused (HUD)', np.nan, inplace=True)

# remove missing data
data.dropna(inplace=True)

# calculate duration of people
data["Entry Date"] = data["Entry Date"].apply(parse_date)
data["Exit Date"] = data["Exit Date"].apply(parse_date)
data["duration"] = (data["Exit Date"] - data["Entry Date"]).apply(stay)
data = data.loc[data['duration']>0]

# rename some column names for later analysis
data.rename(columns={"Client Primary Race": "ClientPrimaryRace", 
                     "Client Ethnicity": "ClientEthnicity", 
                     "Client Veteran Status": "ClientVeteranStatus", 
                     "Client Age at Entry": "ClientAge", 
                     "Client Gender": "ClientGender"}, inplace=True)

# remove HUD tail
data["ClientPrimaryRace"]=data["ClientPrimaryRace"].apply(remove_HUD)
data["ClientEthnicity"]=data["ClientEthnicity"].apply(remove_HUD)
data["ClientVeteranStatus"]=data["ClientVeteranStatus"].apply(remove_HUD)

# %%
# save data
data.to_csv("/Users/jianqiaowang/Documents/GitHub/bios611-projects-fall-2019-Jianqiao-Wang/project_3/scripts/duration.csv")

# %%
# linear model to test effect of different covariates
model = smf.ols(formula='duration~ClientAge+ClientGender+ClientEthnicity+ClientPrimaryRace+ClientVeteranStatus', 
                data=data,).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     9.191
# Date:                Sun, 17 Nov 2019   Prob (F-statistic):           6.14e-14
# Time:                        20:33:48   Log-Likelihood:                -28474.
# No. Observations:                5125   AIC:                         5.697e+04
# Df Residuals:                    5115   BIC:                         5.703e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==================================================================================================================================
#                                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------------------------------------
# Intercept                                                         11.2572      9.075      1.240      0.215      -6.534      29.048
# ClientGender[T.Male]                                              -6.1826      2.086     -2.963      0.003     -10.273      -2.092
# ClientGender[T.Trans Female (MTF or Male to Female)]              -6.6933     15.323     -0.437      0.662     -36.732      23.346
# ClientEthnicity[T.Non-Hispanic/Non-Latino]                        10.9276      4.985      2.192      0.028       1.155      20.700
# ClientPrimaryRace[T.Asian]                                        24.5839     36.844      0.667      0.505     -47.646      96.814
# ClientPrimaryRace[T.Black or African American]                    -1.3704      6.918     -0.198      0.843     -14.932      12.192
# ClientPrimaryRace[T.Native Hawaiian or Other Pacific Islander]    -6.2554     20.996     -0.298      0.766     -47.417      34.906
# ClientPrimaryRace[T.White]                                        -4.3062      7.078     -0.608      0.543     -18.183       9.570
# ClientVeteranStatus[T.Yes]                                        -6.9446      2.958     -2.347      0.019     -12.745      -1.145
# ClientAge                                                          0.5775      0.071      8.142      0.000       0.438       0.717
# ==============================================================================
# Omnibus:                     3839.613   Durbin-Watson:                   1.637
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            81059.215
# Skew:                           3.428   Prob(JB):                         0.00
# Kurtosis:                      21.237   Cond. No.                     1.94e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.94e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
smf.ols(formula='duration~ClientGender', 
                data=data,).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               duration   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.001
# Method:                 Least Squares   F-statistic:                     3.747
# Date:                Sun, 17 Nov 2019   Prob (F-statistic):             0.0236
# Time:                        20:33:55   Log-Likelihood:                -28512.
# No. Observations:                5125   AIC:                         5.703e+04
# Df Residuals:                    5122   BIC:                         5.705e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ========================================================================================================================
#                                                            coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------------
# Intercept                                               44.0338      1.791     24.586      0.000      40.523      47.545
# ClientGender[T.Male]                                    -5.5296      2.058     -2.686      0.007      -9.565      -1.494
# ClientGender[T.Trans Female (MTF or Male to Female)]   -12.2691     15.407     -0.796      0.426     -42.473      17.935
# ==============================================================================
# Omnibus:                     3879.195   Durbin-Watson:                   1.630
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            82989.027
# Skew:                           3.477   Prob(JB):                         0.00
# Kurtosis:                      21.447   Cond. No.                         22.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data2 = pd.read_csv("https://raw.githubusercontent.com/datasci611/bios611-projects-fall-2019-Jianqiao-Wang/master/project_3/data/INCOME_EXIT_191102.tsv", sep="\t")

# %%
data2.dropna(inplace=True)

# %%
data2.head(5)
# Out:
#                                         EE Provider ID  EE UID  \
# 162  Urban Ministries of Durham - Durham County - S...  687909
# 166  Urban Ministries of Durham - Durham County - S...  687911
# 224  Urban Ministries of Durham - Durham County - S...  687914
# 227  Urban Ministries of Durham - Durham County - S...  687951
# 356  Urban Ministries of Durham - Durham County - S...  687982
#
#          Client Unique ID  Client ID ReceivingIncome (Exit)  \
# 162  ctnm05251964c642t534     165730                    Yes
# 166  rcam05241959r200c620     291392                     No
# 224  mgam05151964m240g600     360237                    Yes
# 227  kmlm12231983k150m420     403745                     No
# 356  cohf02011960c530o355     395548                    Yes
#
#     Source of Income (Exit)  Monthly Amount (Exit) Income Start Date (Exit)  \
# 162               SSI (HUD)                  733.0                2/28/1979
# 166     Earned Income (HUD)                  800.0                 8/1/2015
# 224     Earned Income (HUD)                  380.0                 3/8/2015
# 227     Earned Income (HUD)                 1200.0                8/12/2015
# 356              SSDI (HUD)                  847.0                 6/1/2006
#
#     Income End Date (Exit)  Recordset ID (140-recordset_id)  \
# 162             12/31/2017                          1715660
# 166              12/4/2018                          3431695
# 224             11/25/2015                          1900332
# 227              9/15/2015                          2442837
# 356              3/21/2019                          1821447
#
#                                Provider (140-provider)  \
# 162   Urban Ministries of Durham - Durham County(1562)
# 166  Urban Ministries of Durham - Durham County - S...
# 224   Urban Ministries of Durham - Durham County(1562)
# 227  Urban Ministries of Durham - Durham County - S...
# 356   Urban Ministries of Durham - Durham County(1562)
#
#     Date Added (140-date_added)
# 162                    3/2/2015
# 166                    2/9/2016
# 224                    4/8/2015
# 227                   8/19/2015
# 356                   3/23/2015

# %%
# Out:
#       Client ID Entry Date  Exit Date  Client ID  ClientAge ClientGender  \
# 0        397941 2015-08-15 2016-07-11     397941       60.0       Female
# 1        130335 2015-08-15 2015-08-31     130335       48.0       Female
# 2        188933 2015-08-15 2015-09-19     188933       42.0       Female
# 3        168290 2015-08-15 2016-03-07     168290       57.0         Male
# 4        123122 2015-08-15 2015-08-24     123122       51.0         Male
# 5        363382 2015-08-15 2015-10-29     363382       30.0         Male
# 6        165730 2015-08-15 2015-09-06     165730       51.0         Male
# 7        291392 2015-08-15 2015-08-22     291392       56.0         Male
# 8        359808 2015-08-15 2015-10-29     359808       60.0         Male
# 9        385539 2015-08-15 2015-09-23     385539       59.0         Male
# 10       360237 2015-08-15 2015-10-08     360237       51.0         Male
# 11       403745 2015-08-15 2015-08-25     403745       31.0         Male
# 12       404039 2015-08-15 2015-10-05     404039       44.0       Female
# 13       381869 2015-08-15 2015-09-25     381869       75.0       Female
# 14       397313 2015-08-15 2015-09-01     397313       40.0       Female
# 15       185069 2015-08-15 2016-05-25     185069       42.0       Female
# 16       399028 2015-08-15 2016-04-20     399028       51.0       Female
# 17       361024 2015-08-15 2015-10-08     361024       50.0       Female
# 18       324453 2015-08-15 2015-09-03     324453       45.0         Male
# 19       395548 2015-08-15 2015-09-03     395548       55.0       Female
# 20       393111 2015-08-15 2015-12-07     393111       49.0         Male
# 21       379956 2015-08-15 2015-10-03     379956       50.0         Male
# 22       397202 2015-08-15 2015-10-31     397202       26.0         Male
# 23       251488 2015-08-15 2015-11-06     251488       49.0         Male
# 24       395541 2015-08-15 2016-02-04     395541       61.0         Male
# 25       381870 2015-08-15 2015-09-25     381870       53.0         Male
# 26       392383 2015-08-15 2015-08-23     392383       53.0         Male
# 27       318262 2015-08-15 2015-08-31     318262       36.0         Male
# 28       381470 2015-08-15 2015-08-18     381470       58.0         Male
# 29       309651 2015-08-15 2015-10-07     309651       26.0         Male
# ...         ...        ...        ...        ...        ...          ...
# 5268     278004 2015-07-06 2015-08-14     278004       43.0       Female
# 5269     367659 2015-07-06 2015-08-10     367659       46.0       Female
# 5270     401494 2015-07-06 2015-08-10     401494       19.0         Male
# 5271     401763 2015-07-06 2015-08-14     401763       53.0       Female
# 5272     224787 2015-07-06 2015-08-14     224787       65.0         Male
# 5274     384147 2015-07-01 2015-08-14     384147       59.0         Male
# 5275     403049 2015-07-21 2015-08-14     403049       63.0         Male
# 5276     399904 2015-07-21 2015-08-14     399904       58.0         Male
# 5277     403050 2015-07-21 2015-08-14     403050       23.0         Male
# 5278     403483 2015-07-21 2015-08-14     403483       46.0         Male
# 5279     281794 2015-07-23 2015-08-04     281794       44.0         Male
# 5280     404217 2015-07-23 2015-08-14     404217       25.0         Male
# 5281     225552 2015-07-23 2015-08-14     225552       51.0         Male
# 5282     341407 2015-07-23 2015-08-14     341407       26.0         Male
# 5283     390302 2015-07-23 2015-08-14     390302       46.0       Female
# 5284     363078 2014-05-01 2015-01-30     363078       62.0         Male
# 5285     291392 2014-10-23 2015-08-14     291392       55.0         Male
# 5286     382261 2014-10-23 2015-08-07     382261       49.0         Male
# 5287     359808 2014-12-31 2015-08-14     359808       59.0         Male
# 5288     385539 2014-12-31 2015-01-19     385539       58.0         Male
# 5289     373730 2015-01-21 2015-03-08     373730       26.0         Male
# 5290     393036 2015-03-05 2015-06-15     393036       63.0         Male
# 5291     360237 2015-03-05 2015-08-14     360237       50.0         Male
# 5292     385539 2015-01-26 2015-08-14     385539       58.0         Male
# 5293     111217 2015-04-17 2015-08-14     111217       54.0         Male
# 5294     370291 2015-05-12 2015-06-10     370291       68.0         Male
# 5295     175198 2015-06-09 2015-07-13     175198       61.0         Male
# 5296     401978 2015-07-06 2015-07-24     401978       54.0         Male
# 5297     401495 2015-07-01 2015-08-14     401495       49.0         Male
# 5298     403361 2015-07-21 2015-08-14     403361       52.0         Male
#
#                      ClientPrimaryRace          ClientEthnicity  \
# 0                                White  Non-Hispanic/Non-Latino
# 1            Black or African American  Non-Hispanic/Non-Latino
# 2            Black or African American  Non-Hispanic/Non-Latino
# 3                                White          Hispanic/Latino
# 4                                White  Non-Hispanic/Non-Latino
# 5            Black or African American  Non-Hispanic/Non-Latino
# 6            Black or African American  Non-Hispanic/Non-Latino
# 7            Black or African American  Non-Hispanic/Non-Latino
# 8            Black or African American  Non-Hispanic/Non-Latino
# 9            Black or African American  Non-Hispanic/Non-Latino
# 10           Black or African American  Non-Hispanic/Non-Latino
# 11           Black or African American  Non-Hispanic/Non-Latino
# 12           Black or African American  Non-Hispanic/Non-Latino
# 13                               White  Non-Hispanic/Non-Latino
# 14           Black or African American  Non-Hispanic/Non-Latino
# 15           Black or African American  Non-Hispanic/Non-Latino
# 16                               White  Non-Hispanic/Non-Latino
# 17           Black or African American  Non-Hispanic/Non-Latino
# 18           Black or African American  Non-Hispanic/Non-Latino
# 19           Black or African American  Non-Hispanic/Non-Latino
# 20                               White  Non-Hispanic/Non-Latino
# 21           Black or African American  Non-Hispanic/Non-Latino
# 22           Black or African American  Non-Hispanic/Non-Latino
# 23           Black or African American  Non-Hispanic/Non-Latino
# 24           Black or African American  Non-Hispanic/Non-Latino
# 25                               White  Non-Hispanic/Non-Latino
# 26           Black or African American  Non-Hispanic/Non-Latino
# 27           Black or African American  Non-Hispanic/Non-Latino
# 28           Black or African American  Non-Hispanic/Non-Latino
# 29           Black or African American  Non-Hispanic/Non-Latino
# ...                                ...                      ...
# 5268         Black or African American  Non-Hispanic/Non-Latino
# 5269         Black or African American  Non-Hispanic/Non-Latino
# 5270         Black or African American  Non-Hispanic/Non-Latino
# 5271                             White  Non-Hispanic/Non-Latino
# 5272         Black or African American  Non-Hispanic/Non-Latino
# 5274                             White  Non-Hispanic/Non-Latino
# 5275         Black or African American  Non-Hispanic/Non-Latino
# 5276         Black or African American  Non-Hispanic/Non-Latino
# 5277  American Indian or Alaska Native  Non-Hispanic/Non-Latino
# 5278         Black or African American  Non-Hispanic/Non-Latino
# 5279                             White  Non-Hispanic/Non-Latino
# 5280         Black or African American  Non-Hispanic/Non-Latino
# 5281         Black or African American  Non-Hispanic/Non-Latino
# 5282         Black or African American  Non-Hispanic/Non-Latino
# 5283         Black or African American  Non-Hispanic/Non-Latino
# 5284         Black or African American  Non-Hispanic/Non-Latino
# 5285         Black or African American  Non-Hispanic/Non-Latino
# 5286         Black or African American  Non-Hispanic/Non-Latino
# 5287         Black or African American  Non-Hispanic/Non-Latino
# 5288         Black or African American  Non-Hispanic/Non-Latino
# 5289         Black or African American  Non-Hispanic/Non-Latino
# 5290         Black or African American  Non-Hispanic/Non-Latino
# 5291         Black or African American  Non-Hispanic/Non-Latino
# 5292         Black or African American  Non-Hispanic/Non-Latino
# 5293         Black or African American  Non-Hispanic/Non-Latino
# 5294         Black or African American  Non-Hispanic/Non-Latino
# 5295         Black or African American  Non-Hispanic/Non-Latino
# 5296                             White  Non-Hispanic/Non-Latino
# 5297         Black or African American  Non-Hispanic/Non-Latino
# 5298         Black or African American  Non-Hispanic/Non-Latino
#
#      ClientVeteranStatus  duration
# 0                     No       331
# 1                     No        16
# 2                     No        35
# 3                     No       205
# 4                     No         9
# 5                     No        75
# 6                     No        22
# 7                    Yes         7
# 8                    Yes        75
# 9                    Yes        39
# 10                   Yes        54
# 11                    No        10
# 12                    No        51
# 13                    No        41
# 14                    No        17
# 15                    No       284
# 16                    No       249
# 17                    No        54
# 18                    No        19
# 19                    No        19
# 20                    No       114
# 21                    No        49
# 22                    No        77
# 23                    No        83
# 24                    No       173
# 25                    No        41
# 26                    No         8
# 27                    No        16
# 28                   Yes         3
# 29                    No        53
# ...                  ...       ...
# 5268                  No        39
# 5269                  No        35
# 5270                  No        35
# 5271                  No        39
# 5272                  No        39
# 5274                  No        44
# 5275                  No        24
# 5276                  No        24
# 5277                  No        24
# 5278                  No        24
# 5279                  No        12
# 5280                  No        22
# 5281                  No        22
# 5282                  No        22
# 5283                  No        22
# 5284                 Yes       274
# 5285                 Yes       295
# 5286                 Yes       288
# 5287                 Yes       226
# 5288                 Yes        19
# 5289                 Yes        46
# 5290                 Yes       102
# 5291                 Yes       162
# 5292                 Yes       200
# 5293                 Yes       119
# 5294                 Yes        29
# 5295                 Yes        34
# 5296                 Yes        18
# 5297                 Yes        44
# 5298                 Yes        24
#
# [5125 rows x 10 columns]
